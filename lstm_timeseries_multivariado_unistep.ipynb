# %% [markdown]
# <a href="https://colab.research.google.com/github/midiazdi/LSTM-networks/blob/master/lstm_timeseries_multivariado_unistep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##1. Lectura del set de datos

# %%
from google.colab import drive
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np



# Leer set de datos

df = pd.read_csv('weather_dataset_preprocesado.csv', index_col='datetime')
df
# Out:
#                      p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# datetime
# 2009-01-01 01:00:00    996.50     -8.05    265.38        -8.78   94.40
# 2009-01-01 02:00:00    996.62     -8.88    264.54        -9.77   93.20
# 2009-01-01 03:00:00    996.84     -8.81    264.59        -9.66   93.50
# 2009-01-01 04:00:00    996.99     -9.05    264.34       -10.02   92.60
# 2009-01-01 05:00:00    997.46     -9.63    263.72       -10.65   92.20
# ...                       ...       ...       ...          ...     ...
# 2014-09-24 12:00:00    987.01     13.69    287.92         6.29   60.85
# 2014-09-24 13:00:00    986.55     14.19    288.47         6.80   61.01
# 2014-09-24 14:00:00    986.21     14.99    289.30         6.70   57.54
# 2014-09-24 15:00:00    984.76     15.20    289.63         6.96   57.79
# 2014-09-24 16:00:00    984.61     14.40    288.84         7.00   61.03
#
#                      VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# datetime
# 2009-01-01 01:00:00          3.33          3.14          0.19       1.96
# 2009-01-01 02:00:00          3.12          2.90          0.21       1.81
# 2009-01-01 03:00:00          3.13          2.93          0.20       1.83
# 2009-01-01 04:00:00          3.07          2.85          0.23       1.78
# 2009-01-01 05:00:00          2.94          2.71          0.23       1.69
# ...                           ...           ...           ...        ...
# 2014-09-24 12:00:00         15.69          9.55          6.14       6.04
# 2014-09-24 13:00:00         16.21          9.89          6.32       6.26
# 2014-09-24 14:00:00         17.07          9.82          7.25       6.22
# 2014-09-24 15:00:00         17.30         10.00          7.30       6.34
# 2014-09-24 16:00:00         16.43         10.03          6.40       6.36
#
#                      H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  \
# datetime
# 2009-01-01 01:00:00             3.15       1307.86      0.21           0.63
# 2009-01-01 02:00:00             2.91       1312.25      0.25           0.63
# 2009-01-01 03:00:00             2.94       1312.18      0.18           0.63
# 2009-01-01 04:00:00             2.85       1313.61      0.10           0.38
# 2009-01-01 05:00:00             2.71       1317.19      0.40           0.88
# ...                              ...           ...       ...            ...
# 2014-09-24 12:00:00             9.67       1194.28      2.92           4.00
# 2014-09-24 13:00:00            10.02       1191.48      1.57           2.48
# 2014-09-24 14:00:00             9.96       1187.80      2.79           4.75
# 2014-09-24 15:00:00            10.15       1185.10      2.86           4.32
# 2014-09-24 16:00:00            10.18       1188.20      1.71           2.44
#
#                      wd (deg)
# datetime
# 2009-01-01 01:00:00     192.7
# 2009-01-01 02:00:00     190.3
# 2009-01-01 03:00:00     167.2
# 2009-01-01 04:00:00     240.0
# 2009-01-01 05:00:00     157.0
# ...                       ...
# 2014-09-24 12:00:00     174.1
# 2014-09-24 13:00:00     173.0
# 2014-09-24 14:00:00     202.5
# 2014-09-24 15:00:00     172.0
# 2014-09-24 16:00:00     195.1
#
# [50224 rows x 14 columns]

# %% [markdown]
# En este caso **NO** incluiremos la variable tiempo como una covariable, así que podremos eliminarla:

# %%
df = df.reset_index()
df = df.drop(columns=['datetime'])
df
# Out:
#        p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 0        996.50     -8.05    265.38        -8.78   94.40          3.33
# 1        996.62     -8.88    264.54        -9.77   93.20          3.12
# 2        996.84     -8.81    264.59        -9.66   93.50          3.13
# 3        996.99     -9.05    264.34       -10.02   92.60          3.07
# 4        997.46     -9.63    263.72       -10.65   92.20          2.94
# ...         ...       ...       ...          ...     ...           ...
# 50219    987.01     13.69    287.92         6.29   60.85         15.69
# 50220    986.55     14.19    288.47         6.80   61.01         16.21
# 50221    986.21     14.99    289.30         6.70   57.54         17.07
# 50222    984.76     15.20    289.63         6.96   57.79         17.30
# 50223    984.61     14.40    288.84         7.00   61.03         16.43
#
#        VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 0              3.14          0.19       1.96             3.15       1307.86
# 1              2.90          0.21       1.81             2.91       1312.25
# 2              2.93          0.20       1.83             2.94       1312.18
# 3              2.85          0.23       1.78             2.85       1313.61
# 4              2.71          0.23       1.69             2.71       1317.19
# ...             ...           ...        ...              ...           ...
# 50219          9.55          6.14       6.04             9.67       1194.28
# 50220          9.89          6.32       6.26            10.02       1191.48
# 50221          9.82          7.25       6.22             9.96       1187.80
# 50222         10.00          7.30       6.34            10.15       1185.10
# 50223         10.03          6.40       6.36            10.18       1188.20
#
#        wv (m/s)  max. wv (m/s)  wd (deg)
# 0          0.21           0.63     192.7
# 1          0.25           0.63     190.3
# 2          0.18           0.63     167.2
# 3          0.10           0.38     240.0
# 4          0.40           0.88     157.0
# ...         ...            ...       ...
# 50219      2.92           4.00     174.1
# 50220      1.57           2.48     173.0
# 50221      2.79           4.75     202.5
# 50222      2.86           4.32     172.0
# 50223      1.71           2.44     195.1
#
# [50224 rows x 14 columns]

# %% [markdown]
# ## 2. *Feature engineering*

# %%
# Feature engineering
w_dir = df['wd (deg)']*np.pi/180
Wx = df['wv (m/s)']*np.cos(w_dir)
Wy = df['wv (m/s)']*np.sin(w_dir)

# Eliminar columnas irrelevantes
df.pop('wd (deg)')
df.pop('wv (m/s)')
df.pop('max. wv (m/s)')

# E incluir las columnas de interés
df['Wx'] = Wx
df['Wy'] = Wy
df
# Out:
#        p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 0        996.50     -8.05    265.38        -8.78   94.40          3.33
# 1        996.62     -8.88    264.54        -9.77   93.20          3.12
# 2        996.84     -8.81    264.59        -9.66   93.50          3.13
# 3        996.99     -9.05    264.34       -10.02   92.60          3.07
# 4        997.46     -9.63    263.72       -10.65   92.20          2.94
# ...         ...       ...       ...          ...     ...           ...
# 50219    987.01     13.69    287.92         6.29   60.85         15.69
# 50220    986.55     14.19    288.47         6.80   61.01         16.21
# 50221    986.21     14.99    289.30         6.70   57.54         17.07
# 50222    984.76     15.20    289.63         6.96   57.79         17.30
# 50223    984.61     14.40    288.84         7.00   61.03         16.43
#
#        VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 0              3.14          0.19       1.96             3.15       1307.86
# 1              2.90          0.21       1.81             2.91       1312.25
# 2              2.93          0.20       1.83             2.94       1312.18
# 3              2.85          0.23       1.78             2.85       1313.61
# 4              2.71          0.23       1.69             2.71       1317.19
# ...             ...           ...        ...              ...           ...
# 50219          9.55          6.14       6.04             9.67       1194.28
# 50220          9.89          6.32       6.26            10.02       1191.48
# 50221          9.82          7.25       6.22             9.96       1187.80
# 50222         10.00          7.30       6.34            10.15       1185.10
# 50223         10.03          6.40       6.36            10.18       1188.20
#
#              Wx        Wy
# 0     -0.204862 -0.046168
# 1     -0.245971 -0.044701
# 2     -0.175527  0.039879
# 3     -0.050000 -0.086603
# 4     -0.368202  0.156292
# ...         ...       ...
# 50219 -2.904532  0.300154
# 50220 -1.558297  0.191335
# 50221 -2.577624 -1.067687
# 50222 -2.832167  0.398035
# 50223 -1.650958 -0.445463
#
# [50224 rows x 13 columns]

# %% [markdown]
# ##3. Pre-procesamiento

# %% [markdown]
# ### 3.1. Partición del set en entrenamiento, validación y prueba

# %%
# Función para generar las particiones preservando las características
# de la serie de tiempo

def train_val_test_split(dataframe, tr_size=0.8, vl_size=0.1, ts_size=0.1 ):
    # Definir número de datos en cada subserie
    N = dataframe.shape[0]
    Ntrain = int(tr_size*N)  # Número de datos de entrenamiento
    Nval = int(vl_size*N)    # Número de datos de validación
    Ntst = N - Ntrain - Nval # Número de datos de prueba

    # Realizar partición
    train = dataframe[0:Ntrain]
    val = dataframe[Ntrain:Ntrain+Nval]
    test = dataframe[Ntrain+Nval:]

    return train, val, test

# Prueba de la función
tr, vl, ts = train_val_test_split(df)

print(f'Tamaño set de entrenamiento: {tr.shape}')
print(f'Tamaño set de validación: {vl.shape}')
print(f'Tamaño set de prueba: {ts.shape}')
# Out:
# Tamaño set de entrenamiento: (40179, 13)
# Tamaño set de validación: (5022, 13)
# Tamaño set de prueba: (5023, 13)

# %%
covar = 1 # Índice de la covariable (columna del dataset) a graficar
col = df.columns[covar]

# Dibujar los sets de entrenamiento/validación/prueba para la covariable
fig, ax = plt.subplots(figsize = (16,5))
ax.plot(tr[col], label='Train')
ax.plot(vl[col], label='Val')
ax.plot(ts[col], label='Test')
ax.set_title(f'Covariable: {col}')
plt.legend();

# %% [markdown]
# ###3.2 Generación del dataset supervisado (entrada y salida del modelo)

# %%
def crear_dataset_supervisado(array, input_length, output_length):
    '''Permite crear un dataset con las entradas (X) y salidas (Y)
    requeridas por la Red LSTM.

    Parámetros:
    - array: arreglo numpy de tamaño N x features (N: cantidad de datos,
      f: cantidad de features)
    - input_length: instantes de tiempo consecutivos de la(s) serie(s) de tiempo
      usados para alimentar el modelo
    - output_length: instantes de tiempo a pronosticar (salida del modelo)
    '''

    # Inicialización
    X, Y = [], []    # Listados que contendrán los datos de entrada y salida del modelo
    shape = array.shape
    if len(shape)==1: # Si tenemos sólo una serie (univariado)
        fils, cols = array.shape[0], 1
        array = array.reshape(fils,cols)
    else: # Multivariado <-- <--- ¡esta parte de la función se ejecuta en este caso!
        fils, cols = array.shape

    # Generar los arreglos
    for i in range(fils-input_length-output_length):
        # Entrada al modelo
        X.append(array[i:i+INPUT_LENGTH,0:cols])

        # Salida (el índice 1 corresponde a la columna con la variable a predecir)
        Y.append(array[i+input_length:i+input_length+output_length,1].reshape(output_length,1))

    # Convertir listas a arreglos de NumPy
    X = np.array(X)
    Y = np.array(Y)

    return X, Y

# %%
# Crear los datasets de entrenamiento, prueba y validación y verificar sus tamaños
INPUT_LENGTH = 24    # Hiperparámetro
OUTPUT_LENGTH = 1    # Modelo uni-step

x_tr, y_tr = crear_dataset_supervisado(tr.values, INPUT_LENGTH, OUTPUT_LENGTH)
x_vl, y_vl = crear_dataset_supervisado(vl.values, INPUT_LENGTH, OUTPUT_LENGTH)
x_ts, y_ts = crear_dataset_supervisado(ts.values, INPUT_LENGTH, OUTPUT_LENGTH)

# Imprimir información en pantalla
print('Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)')
print(f'Set de entrenamiento - x_tr: {x_tr.shape}, y_tr: {y_tr.shape}')
print(f'Set de validación - x_vl: {x_vl.shape}, y_vl: {y_vl.shape}')
print(f'Set de prueba - x_ts: {x_ts.shape}, y_ts: {y_ts.shape}')
# Out:
# Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)
# Set de entrenamiento - x_tr: (40154, 24, 13), y_tr: (40154, 1, 1)
# Set de validación - x_vl: (4997, 24, 13), y_vl: (4997, 1, 1)
# Set de prueba - x_ts: (4998, 24, 13), y_ts: (4998, 1, 1)

# %% [markdown]
# ###3.3 Escalamiento

# %%
from sklearn.preprocessing import MinMaxScaler

def escalar_dataset(data_input, col_ref):
    '''Escala el dataset en el rango de -1 a 1.

    Entradas:
    - data_input: diccionario con los dataset de entrada y salida del modelo
    (data_input = {'x_tr':x_tr, 'y_tr':y_tr, 'x_vl':x_vl, 'y_vl':y_vl,
                    'y_ts':y_ts})
    - col_ref: parámetro adicional para especificar la columna que contiene
      la variable a predecir


    Retorna:
    - data_scaled: diccionario con los datasets de entrada y salida escalados
      (tiene la misma estructura del diccionario de entrada)
    - scaler: el escalador usado (requerido para las predicciones)
    '''

    # *** Implementación adicional: determinar el índice de la columna
    # que contiene la variable a predecir
    col_ref = df.columns.get_loc(col_ref)

    # Número de instantes de tiempo de entrada y de covariables
    NFEATS = data_input['x_tr'].shape[2]

    # Generar listado con "scalers" (1 por cada covariable de entrada)
    scalers = [MinMaxScaler(feature_range=(-1,1)) for i in range(NFEATS)]

    # Arreglos que contendrán los datasets escalados
    x_tr_s = np.zeros(data_input['x_tr'].shape)
    x_vl_s = np.zeros(data_input['x_vl'].shape)
    x_ts_s = np.zeros(data_input['x_ts'].shape)
    y_tr_s = np.zeros(data_input['y_tr'].shape)
    y_vl_s = np.zeros(data_input['y_vl'].shape)
    y_ts_s = np.zeros(data_input['y_ts'].shape)

    # Escalamiento: se usarán los min/max del set de entrenamiento para
    # escalar la totalidad de los datasets

    # Escalamiento Xs
    for i in range(NFEATS):
        x_tr_s[:,:,i] = scalers[i].fit_transform(x_tr[:,:,i])
        x_vl_s[:,:,i] = scalers[i].transform(x_vl[:,:,i])
        x_ts_s[:,:,i] = scalers[i].transform(x_ts[:,:,i])

    # Escalamiento Ys (teniendo en cuenta "col_ind")
    y_tr_s[:,:,0] = scalers[col_ref].fit_transform(y_tr[:,:,0])
    y_vl_s[:,:,0] = scalers[col_ref].transform(y_vl[:,:,0])
    y_ts_s[:,:,0] = scalers[col_ref].transform(y_ts[:,:,0])

    # Conformar diccionario de salida
    data_scaled = {
        'x_tr_s': x_tr_s, 'y_tr_s': y_tr_s,
        'x_vl_s': x_vl_s, 'y_vl_s': y_vl_s,
        'x_ts_s': x_ts_s, 'y_ts_s': y_ts_s,
    }

    return data_scaled, scalers[col_ref]

# %%
# Escalamiento del dataset con la función anterior

# Crear diccionario de entrada
data_in = {
    'x_tr': x_tr, 'y_tr': y_tr,
    'x_vl': x_vl, 'y_vl': y_vl,
    'x_ts': x_ts, 'y_ts': y_ts,
}

# Y escalar (especificando la columna con la variable a predecir)
data_s, scaler = escalar_dataset(data_in, col_ref = 'T (degC)' )

# Extraer subsets escalados
x_tr_s, y_tr_s = data_s['x_tr_s'], data_s['y_tr_s']
x_vl_s, y_vl_s = data_s['x_vl_s'], data_s['y_vl_s']
x_ts_s, y_ts_s = data_s['x_ts_s'], data_s['y_ts_s']

# %%
# Y generemos una gráfica tipo violín para ver la distribución
# de los valores en cada covariable (entrada) y en la variable a
# predecir (salida)

fig, ax = plt.subplots(figsize=(12,4))
for i in range(13):
    ax.violinplot(dataset=x_tr_s[:,:,i].flatten(), positions=[i])
    ax.violinplot(dataset=x_vl_s[:,:,i].flatten(), positions=[i])
    ax.violinplot(dataset=x_ts_s[:,:,i].flatten(), positions=[i])

# Etiquetas eje horizontal
ax.set_xticks(list(range(13)))
ax.set_xticklabels(df.keys(), rotation=90)
ax.autoscale();

# %%
# Y hagamos lo mismo con la variable de salida:
fig, ax = plt.subplots(figsize=(6,4))
ax.violinplot(dataset=y_tr_s.flatten())
ax.violinplot(dataset=y_vl_s.flatten())
ax.violinplot(dataset=y_ts_s.flatten())
ax.set_xticks([1])
ax.set_xticklabels(['y (salida)']);

# %% [markdown]
# ##4. Creación y entrenamiento del modelo

# %%
# Creación del modelo
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import RMSprop, Adam
import tensorflow as tf

# Ajustar parámetros para reproducibilidad del entrenamiento
tf.random.set_seed(123)
tf.config.experimental.enable_op_determinism()

# El modelo
N_UNITS = 150 # Tamaño del estado oculto (h) y de la celdad de memoria (c) (128)
INPUT_SHAPE = (x_tr_s.shape[1], x_tr_s.shape[2]) # 24 (horas) x 13 (features)

modelo = Sequential()
modelo.add(LSTM(N_UNITS, input_shape=INPUT_SHAPE))

# Y lo único que cambia con respecto al modelo multivariado + uni-step es
# el tamaño deldato de salida
modelo.add(Dense(OUTPUT_LENGTH, activation='linear')) # activation = 'linear' pues queremos pronosticar (regresión)

# Pérdida: se usará el RMSE (root mean squared error) para el entrenamiento
# pues permite tener errores en las mismas unidades de la temperatura
def root_mean_squared_error(y_true, y_pred):
    rmse = tf.math.sqrt(tf.math.reduce_mean(tf.square(y_pred-y_true)))
    return rmse

# Compilación
optimizador = RMSprop(learning_rate=5e-4) # 5e-5
modelo.compile(
    optimizer = optimizador,
    loss = root_mean_squared_error,
)

# Entrenamiento (aproximadamente 1 min usando GPU)
EPOCHS = 800 # Hiperparámetro
BATCH_SIZE = 300 # Hiperparámetro
historia = modelo.fit(
    x = x_tr_s,
    y = y_tr_s,
    batch_size = BATCH_SIZE,
    epochs = EPOCHS,
    validation_data = (x_vl_s, y_vl_s),
    verbose=2
)
# Out:
# Epoch 1/800
# 134/134 - 3s - loss: 0.0748 - val_loss: 0.0454 - 3s/epoch - 22ms/step
# Epoch 2/800
# 134/134 - 1s - loss: 0.0412 - val_loss: 0.0345 - 705ms/epoch - 5ms/step
# Epoch 3/800
# 134/134 - 1s - loss: 0.0349 - val_loss: 0.0321 - 701ms/epoch - 5ms/step
# Epoch 4/800
# 134/134 - 1s - loss: 0.0316 - val_loss: 0.0268 - 703ms/epoch - 5ms/step
# Epoch 5/800
# 134/134 - 1s - loss: 0.0296 - val_loss: 0.0256 - 683ms/epoch - 5ms/step
# Epoch 6/800
# 134/134 - 1s - loss: 0.0283 - val_loss: 0.0249 - 745ms/epoch - 6ms/step
# Epoch 7/800
# 134/134 - 1s - loss: 0.0275 - val_loss: 0.0240 - 810ms/epoch - 6ms/step
# Epoch 8/800
# 134/134 - 1s - loss: 0.0271 - val_loss: 0.0255 - 790ms/epoch - 6ms/step
# Epoch 9/800
# 134/134 - 1s - loss: 0.0267 - val_loss: 0.0236 - 751ms/epoch - 6ms/step
# Epoch 10/800
# 134/134 - 1s - loss: 0.0264 - val_loss: 0.0264 - 711ms/epoch - 5ms/step
# Epoch 11/800
# 134/134 - 1s - loss: 0.0261 - val_loss: 0.0232 - 697ms/epoch - 5ms/step
# Epoch 12/800
# 134/134 - 1s - loss: 0.0259 - val_loss: 0.0256 - 693ms/epoch - 5ms/step
# Epoch 13/800
# 134/134 - 1s - loss: 0.0258 - val_loss: 0.0232 - 688ms/epoch - 5ms/step
# Epoch 14/800
# 134/134 - 1s - loss: 0.0256 - val_loss: 0.0232 - 703ms/epoch - 5ms/step
# Epoch 15/800
# 134/134 - 1s - loss: 0.0255 - val_loss: 0.0237 - 691ms/epoch - 5ms/step
# Epoch 16/800
# 134/134 - 1s - loss: 0.0254 - val_loss: 0.0243 - 678ms/epoch - 5ms/step
# Epoch 17/800
# 134/134 - 1s - loss: 0.0253 - val_loss: 0.0260 - 694ms/epoch - 5ms/step
# Epoch 18/800
# 134/134 - 1s - loss: 0.0253 - val_loss: 0.0244 - 692ms/epoch - 5ms/step
# Epoch 19/800
# 134/134 - 1s - loss: 0.0252 - val_loss: 0.0237 - 715ms/epoch - 5ms/step
# Epoch 20/800
# 134/134 - 1s - loss: 0.0251 - val_loss: 0.0239 - 699ms/epoch - 5ms/step
# Epoch 21/800
# 134/134 - 1s - loss: 0.0250 - val_loss: 0.0254 - 678ms/epoch - 5ms/step
# Epoch 22/800
# 134/134 - 1s - loss: 0.0250 - val_loss: 0.0233 - 705ms/epoch - 5ms/step
# Epoch 23/800
# 134/134 - 1s - loss: 0.0248 - val_loss: 0.0228 - 858ms/epoch - 6ms/step
# Epoch 24/800
# 134/134 - 1s - loss: 0.0248 - val_loss: 0.0251 - 818ms/epoch - 6ms/step
# Epoch 25/800
# 134/134 - 1s - loss: 0.0247 - val_loss: 0.0234 - 824ms/epoch - 6ms/step
# Epoch 26/800
# 134/134 - 1s - loss: 0.0247 - val_loss: 0.0228 - 700ms/epoch - 5ms/step
# Epoch 27/800
# 134/134 - 1s - loss: 0.0247 - val_loss: 0.0233 - 685ms/epoch - 5ms/step
# Epoch 28/800
# 134/134 - 1s - loss: 0.0246 - val_loss: 0.0228 - 689ms/epoch - 5ms/step
# Epoch 29/800
# 134/134 - 1s - loss: 0.0246 - val_loss: 0.0228 - 709ms/epoch - 5ms/step
# Epoch 30/800
# 134/134 - 1s - loss: 0.0245 - val_loss: 0.0229 - 690ms/epoch - 5ms/step
# Epoch 31/800
# 134/134 - 1s - loss: 0.0245 - val_loss: 0.0225 - 707ms/epoch - 5ms/step
# Epoch 32/800
# 134/134 - 1s - loss: 0.0245 - val_loss: 0.0226 - 717ms/epoch - 5ms/step
# Epoch 33/800
# 134/134 - 1s - loss: 0.0244 - val_loss: 0.0228 - 726ms/epoch - 5ms/step
# Epoch 34/800
# 134/134 - 1s - loss: 0.0244 - val_loss: 0.0231 - 694ms/epoch - 5ms/step
# Epoch 35/800
# 134/134 - 1s - loss: 0.0244 - val_loss: 0.0234 - 687ms/epoch - 5ms/step
# Epoch 36/800
# 134/134 - 1s - loss: 0.0244 - val_loss: 0.0230 - 691ms/epoch - 5ms/step
# Epoch 37/800
# 134/134 - 1s - loss: 0.0244 - val_loss: 0.0241 - 703ms/epoch - 5ms/step
# Epoch 38/800
# 134/134 - 1s - loss: 0.0243 - val_loss: 0.0227 - 684ms/epoch - 5ms/step
# Epoch 39/800
# 134/134 - 1s - loss: 0.0243 - val_loss: 0.0227 - 714ms/epoch - 5ms/step
# Epoch 40/800
# 134/134 - 1s - loss: 0.0242 - val_loss: 0.0234 - 770ms/epoch - 6ms/step
# Epoch 41/800
# 134/134 - 1s - loss: 0.0242 - val_loss: 0.0229 - 787ms/epoch - 6ms/step
# Epoch 42/800
# 134/134 - 1s - loss: 0.0242 - val_loss: 0.0232 - 941ms/epoch - 7ms/step
# Epoch 43/800
# 134/134 - 1s - loss: 0.0242 - val_loss: 0.0236 - 676ms/epoch - 5ms/step
# Epoch 44/800
# 134/134 - 1s - loss: 0.0242 - val_loss: 0.0225 - 725ms/epoch - 5ms/step
# Epoch 45/800
# 134/134 - 1s - loss: 0.0242 - val_loss: 0.0228 - 683ms/epoch - 5ms/step
# Epoch 46/800
# 134/134 - 1s - loss: 0.0242 - val_loss: 0.0241 - 691ms/epoch - 5ms/step
# Epoch 47/800
# 134/134 - 1s - loss: 0.0241 - val_loss: 0.0227 - 679ms/epoch - 5ms/step
# Epoch 48/800
# 134/134 - 1s - loss: 0.0241 - val_loss: 0.0234 - 729ms/epoch - 5ms/step
# Epoch 49/800
# 134/134 - 1s - loss: 0.0241 - val_loss: 0.0233 - 676ms/epoch - 5ms/step
# Epoch 50/800
# 134/134 - 1s - loss: 0.0241 - val_loss: 0.0233 - 686ms/epoch - 5ms/step
# Epoch 51/800
# 134/134 - 1s - loss: 0.0241 - val_loss: 0.0234 - 695ms/epoch - 5ms/step
# Epoch 52/800
# 134/134 - 1s - loss: 0.0241 - val_loss: 0.0224 - 696ms/epoch - 5ms/step
# Epoch 53/800
# 134/134 - 1s - loss: 0.0241 - val_loss: 0.0223 - 680ms/epoch - 5ms/step
# Epoch 54/800
# 134/134 - 1s - loss: 0.0240 - val_loss: 0.0230 - 689ms/epoch - 5ms/step
# Epoch 55/800
# 134/134 - 1s - loss: 0.0240 - val_loss: 0.0225 - 686ms/epoch - 5ms/step
# Epoch 56/800
# 134/134 - 1s - loss: 0.0240 - val_loss: 0.0228 - 695ms/epoch - 5ms/step
# Epoch 57/800
# 134/134 - 1s - loss: 0.0240 - val_loss: 0.0233 - 759ms/epoch - 6ms/step
# Epoch 58/800
# 134/134 - 1s - loss: 0.0240 - val_loss: 0.0224 - 798ms/epoch - 6ms/step
# Epoch 59/800
# 134/134 - 1s - loss: 0.0240 - val_loss: 0.0230 - 809ms/epoch - 6ms/step
# Epoch 60/800
# 134/134 - 1s - loss: 0.0240 - val_loss: 0.0225 - 707ms/epoch - 5ms/step
# Epoch 61/800
# 134/134 - 1s - loss: 0.0240 - val_loss: 0.0225 - 675ms/epoch - 5ms/step
# Epoch 62/800
# 134/134 - 1s - loss: 0.0240 - val_loss: 0.0230 - 678ms/epoch - 5ms/step
# Epoch 63/800
# 134/134 - 1s - loss: 0.0239 - val_loss: 0.0224 - 700ms/epoch - 5ms/step
# Epoch 64/800
# 134/134 - 1s - loss: 0.0240 - val_loss: 0.0225 - 678ms/epoch - 5ms/step
# Epoch 65/800
# 134/134 - 1s - loss: 0.0239 - val_loss: 0.0227 - 670ms/epoch - 5ms/step
# Epoch 66/800
# 134/134 - 1s - loss: 0.0239 - val_loss: 0.0235 - 678ms/epoch - 5ms/step
# Epoch 67/800
# 134/134 - 1s - loss: 0.0239 - val_loss: 0.0231 - 692ms/epoch - 5ms/step
# Epoch 68/800
# 134/134 - 1s - loss: 0.0239 - val_loss: 0.0237 - 669ms/epoch - 5ms/step
# Epoch 69/800
# 134/134 - 1s - loss: 0.0239 - val_loss: 0.0235 - 677ms/epoch - 5ms/step
# Epoch 70/800
# 134/134 - 1s - loss: 0.0239 - val_loss: 0.0229 - 673ms/epoch - 5ms/step
# Epoch 71/800
# 134/134 - 1s - loss: 0.0238 - val_loss: 0.0229 - 675ms/epoch - 5ms/step
# Epoch 72/800
# 134/134 - 1s - loss: 0.0239 - val_loss: 0.0229 - 679ms/epoch - 5ms/step
# Epoch 73/800
# 134/134 - 1s - loss: 0.0238 - val_loss: 0.0231 - 678ms/epoch - 5ms/step
# Epoch 74/800
# 134/134 - 1s - loss: 0.0238 - val_loss: 0.0225 - 771ms/epoch - 6ms/step
# Epoch 75/800
# 134/134 - 1s - loss: 0.0238 - val_loss: 0.0228 - 790ms/epoch - 6ms/step
# Epoch 76/800
# 134/134 - 1s - loss: 0.0239 - val_loss: 0.0225 - 817ms/epoch - 6ms/step
# Epoch 77/800
# 134/134 - 1s - loss: 0.0238 - val_loss: 0.0226 - 698ms/epoch - 5ms/step
# Epoch 78/800
# 134/134 - 1s - loss: 0.0238 - val_loss: 0.0229 - 669ms/epoch - 5ms/step
# Epoch 79/800
# 134/134 - 1s - loss: 0.0238 - val_loss: 0.0225 - 710ms/epoch - 5ms/step
# Epoch 80/800
# 134/134 - 1s - loss: 0.0238 - val_loss: 0.0224 - 687ms/epoch - 5ms/step
# Epoch 81/800
# 134/134 - 1s - loss: 0.0238 - val_loss: 0.0224 - 672ms/epoch - 5ms/step
# Epoch 82/800
# 134/134 - 1s - loss: 0.0238 - val_loss: 0.0228 - 683ms/epoch - 5ms/step
# Epoch 83/800
# 134/134 - 1s - loss: 0.0238 - val_loss: 0.0224 - 695ms/epoch - 5ms/step
# Epoch 84/800
# 134/134 - 1s - loss: 0.0237 - val_loss: 0.0225 - 668ms/epoch - 5ms/step
# Epoch 85/800
# 134/134 - 1s - loss: 0.0238 - val_loss: 0.0227 - 671ms/epoch - 5ms/step
# Epoch 86/800
# 134/134 - 1s - loss: 0.0237 - val_loss: 0.0228 - 671ms/epoch - 5ms/step
# Epoch 87/800
# 134/134 - 1s - loss: 0.0237 - val_loss: 0.0226 - 670ms/epoch - 5ms/step
# Epoch 88/800
# 134/134 - 1s - loss: 0.0237 - val_loss: 0.0226 - 685ms/epoch - 5ms/step
# Epoch 89/800
# 134/134 - 1s - loss: 0.0237 - val_loss: 0.0231 - 675ms/epoch - 5ms/step
# Epoch 90/800
# 134/134 - 1s - loss: 0.0237 - val_loss: 0.0226 - 688ms/epoch - 5ms/step
# Epoch 91/800
# 134/134 - 1s - loss: 0.0237 - val_loss: 0.0231 - 735ms/epoch - 5ms/step
# Epoch 92/800
# 134/134 - 1s - loss: 0.0237 - val_loss: 0.0226 - 797ms/epoch - 6ms/step
# Epoch 93/800
# 134/134 - 1s - loss: 0.0237 - val_loss: 0.0224 - 797ms/epoch - 6ms/step
# Epoch 94/800
# 134/134 - 1s - loss: 0.0237 - val_loss: 0.0226 - 707ms/epoch - 5ms/step
# Epoch 95/800
# 134/134 - 1s - loss: 0.0237 - val_loss: 0.0227 - 684ms/epoch - 5ms/step
# Epoch 96/800
# 134/134 - 1s - loss: 0.0237 - val_loss: 0.0225 - 681ms/epoch - 5ms/step
# Epoch 97/800
# 134/134 - 1s - loss: 0.0237 - val_loss: 0.0226 - 682ms/epoch - 5ms/step
# Epoch 98/800
# 134/134 - 1s - loss: 0.0237 - val_loss: 0.0227 - 673ms/epoch - 5ms/step
# Epoch 99/800
# 134/134 - 1s - loss: 0.0237 - val_loss: 0.0222 - 694ms/epoch - 5ms/step
# Epoch 100/800
# 134/134 - 1s - loss: 0.0236 - val_loss: 0.0224 - 671ms/epoch - 5ms/step
# Epoch 101/800
# 134/134 - 1s - loss: 0.0236 - val_loss: 0.0225 - 662ms/epoch - 5ms/step
# Epoch 102/800
# 134/134 - 1s - loss: 0.0236 - val_loss: 0.0225 - 674ms/epoch - 5ms/step
# Epoch 103/800
# 134/134 - 1s - loss: 0.0237 - val_loss: 0.0226 - 692ms/epoch - 5ms/step
# Epoch 104/800
# 134/134 - 1s - loss: 0.0237 - val_loss: 0.0232 - 672ms/epoch - 5ms/step
# Epoch 105/800
# 134/134 - 1s - loss: 0.0236 - val_loss: 0.0230 - 687ms/epoch - 5ms/step
# Epoch 106/800
# 134/134 - 1s - loss: 0.0236 - val_loss: 0.0229 - 677ms/epoch - 5ms/step
# Epoch 107/800
# 134/134 - 1s - loss: 0.0236 - val_loss: 0.0232 - 669ms/epoch - 5ms/step
# Epoch 108/800
# 134/134 - 1s - loss: 0.0236 - val_loss: 0.0226 - 702ms/epoch - 5ms/step
# Epoch 109/800
# 134/134 - 1s - loss: 0.0236 - val_loss: 0.0228 - 778ms/epoch - 6ms/step
# Epoch 110/800
# 134/134 - 1s - loss: 0.0236 - val_loss: 0.0225 - 784ms/epoch - 6ms/step
# Epoch 111/800
# 134/134 - 1s - loss: 0.0235 - val_loss: 0.0223 - 755ms/epoch - 6ms/step
# Epoch 112/800
# 134/134 - 1s - loss: 0.0236 - val_loss: 0.0221 - 687ms/epoch - 5ms/step
# Epoch 113/800
# 134/134 - 1s - loss: 0.0236 - val_loss: 0.0223 - 675ms/epoch - 5ms/step
# Epoch 114/800
# 134/134 - 1s - loss: 0.0236 - val_loss: 0.0227 - 671ms/epoch - 5ms/step
# Epoch 115/800
# 134/134 - 1s - loss: 0.0236 - val_loss: 0.0228 - 683ms/epoch - 5ms/step
# Epoch 116/800
# 134/134 - 1s - loss: 0.0235 - val_loss: 0.0228 - 673ms/epoch - 5ms/step
# Epoch 117/800
# 134/134 - 1s - loss: 0.0236 - val_loss: 0.0226 - 674ms/epoch - 5ms/step
# Epoch 118/800
# 134/134 - 1s - loss: 0.0236 - val_loss: 0.0223 - 696ms/epoch - 5ms/step
# Epoch 119/800
# 134/134 - 1s - loss: 0.0235 - val_loss: 0.0224 - 669ms/epoch - 5ms/step
# Epoch 120/800
# 134/134 - 1s - loss: 0.0236 - val_loss: 0.0224 - 705ms/epoch - 5ms/step
# Epoch 121/800
# 134/134 - 1s - loss: 0.0235 - val_loss: 0.0224 - 692ms/epoch - 5ms/step
# Epoch 122/800
# 134/134 - 1s - loss: 0.0235 - val_loss: 0.0229 - 702ms/epoch - 5ms/step
# Epoch 123/800
# 134/134 - 1s - loss: 0.0235 - val_loss: 0.0222 - 688ms/epoch - 5ms/step
# Epoch 124/800
# 134/134 - 1s - loss: 0.0235 - val_loss: 0.0223 - 700ms/epoch - 5ms/step
# Epoch 125/800
# 134/134 - 1s - loss: 0.0235 - val_loss: 0.0224 - 686ms/epoch - 5ms/step
# Epoch 126/800
# 134/134 - 1s - loss: 0.0235 - val_loss: 0.0232 - 805ms/epoch - 6ms/step
# Epoch 127/800
# 134/134 - 1s - loss: 0.0235 - val_loss: 0.0224 - 785ms/epoch - 6ms/step
# Epoch 128/800
# 134/134 - 1s - loss: 0.0235 - val_loss: 0.0224 - 805ms/epoch - 6ms/step
# Epoch 129/800
# 134/134 - 1s - loss: 0.0235 - val_loss: 0.0225 - 693ms/epoch - 5ms/step
# Epoch 130/800
# 134/134 - 1s - loss: 0.0235 - val_loss: 0.0223 - 685ms/epoch - 5ms/step
# Epoch 131/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0225 - 699ms/epoch - 5ms/step
# Epoch 132/800
# 134/134 - 1s - loss: 0.0235 - val_loss: 0.0227 - 695ms/epoch - 5ms/step
# Epoch 133/800
# 134/134 - 1s - loss: 0.0235 - val_loss: 0.0222 - 676ms/epoch - 5ms/step
# Epoch 134/800
# 134/134 - 1s - loss: 0.0235 - val_loss: 0.0224 - 678ms/epoch - 5ms/step
# Epoch 135/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0222 - 672ms/epoch - 5ms/step
# Epoch 136/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0227 - 668ms/epoch - 5ms/step
# Epoch 137/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0225 - 677ms/epoch - 5ms/step
# Epoch 138/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0223 - 676ms/epoch - 5ms/step
# Epoch 139/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0223 - 672ms/epoch - 5ms/step
# Epoch 140/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0223 - 678ms/epoch - 5ms/step
# Epoch 141/800
# 134/134 - 1s - loss: 0.0235 - val_loss: 0.0224 - 685ms/epoch - 5ms/step
# Epoch 142/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0225 - 687ms/epoch - 5ms/step
# Epoch 143/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0222 - 768ms/epoch - 6ms/step
# Epoch 144/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0223 - 782ms/epoch - 6ms/step
# Epoch 145/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0227 - 767ms/epoch - 6ms/step
# Epoch 146/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0224 - 665ms/epoch - 5ms/step
# Epoch 147/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0221 - 704ms/epoch - 5ms/step
# Epoch 148/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0224 - 691ms/epoch - 5ms/step
# Epoch 149/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0226 - 694ms/epoch - 5ms/step
# Epoch 150/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0222 - 697ms/epoch - 5ms/step
# Epoch 151/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0222 - 677ms/epoch - 5ms/step
# Epoch 152/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0223 - 674ms/epoch - 5ms/step
# Epoch 153/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0223 - 676ms/epoch - 5ms/step
# Epoch 154/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0222 - 690ms/epoch - 5ms/step
# Epoch 155/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0221 - 695ms/epoch - 5ms/step
# Epoch 156/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0225 - 675ms/epoch - 5ms/step
# Epoch 157/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0226 - 675ms/epoch - 5ms/step
# Epoch 158/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0224 - 669ms/epoch - 5ms/step
# Epoch 159/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0224 - 675ms/epoch - 5ms/step
# Epoch 160/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0229 - 762ms/epoch - 6ms/step
# Epoch 161/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0224 - 799ms/epoch - 6ms/step
# Epoch 162/800
# 134/134 - 1s - loss: 0.0234 - val_loss: 0.0225 - 691ms/epoch - 5ms/step
# Epoch 163/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0222 - 703ms/epoch - 5ms/step
# Epoch 164/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0221 - 677ms/epoch - 5ms/step
# Epoch 165/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0223 - 703ms/epoch - 5ms/step
# Epoch 166/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0223 - 698ms/epoch - 5ms/step
# Epoch 167/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0224 - 680ms/epoch - 5ms/step
# Epoch 168/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0223 - 676ms/epoch - 5ms/step
# Epoch 169/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0226 - 691ms/epoch - 5ms/step
# Epoch 170/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0226 - 672ms/epoch - 5ms/step
# Epoch 171/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0222 - 669ms/epoch - 5ms/step
# Epoch 172/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0226 - 678ms/epoch - 5ms/step
# Epoch 173/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0225 - 681ms/epoch - 5ms/step
# Epoch 174/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0221 - 674ms/epoch - 5ms/step
# Epoch 175/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0223 - 682ms/epoch - 5ms/step
# Epoch 176/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0220 - 743ms/epoch - 6ms/step
# Epoch 177/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0223 - 789ms/epoch - 6ms/step
# Epoch 178/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0227 - 730ms/epoch - 5ms/step
# Epoch 179/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0223 - 685ms/epoch - 5ms/step
# Epoch 180/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0224 - 698ms/epoch - 5ms/step
# Epoch 181/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0223 - 676ms/epoch - 5ms/step
# Epoch 182/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0224 - 679ms/epoch - 5ms/step
# Epoch 183/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0225 - 700ms/epoch - 5ms/step
# Epoch 184/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0225 - 701ms/epoch - 5ms/step
# Epoch 185/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0221 - 672ms/epoch - 5ms/step
# Epoch 186/800
# 134/134 - 1s - loss: 0.0233 - val_loss: 0.0227 - 679ms/epoch - 5ms/step
# Epoch 187/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0223 - 671ms/epoch - 5ms/step
# Epoch 188/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0224 - 671ms/epoch - 5ms/step
# Epoch 189/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0227 - 701ms/epoch - 5ms/step
# Epoch 190/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0226 - 680ms/epoch - 5ms/step
# Epoch 191/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0228 - 699ms/epoch - 5ms/step
# Epoch 192/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0222 - 793ms/epoch - 6ms/step
# Epoch 193/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0223 - 808ms/epoch - 6ms/step
# Epoch 194/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0224 - 734ms/epoch - 5ms/step
# Epoch 195/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0221 - 681ms/epoch - 5ms/step
# Epoch 196/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0223 - 697ms/epoch - 5ms/step
# Epoch 197/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0226 - 669ms/epoch - 5ms/step
# Epoch 198/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0225 - 674ms/epoch - 5ms/step
# Epoch 199/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0224 - 670ms/epoch - 5ms/step
# Epoch 200/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0221 - 690ms/epoch - 5ms/step
# Epoch 201/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0224 - 673ms/epoch - 5ms/step
# Epoch 202/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0224 - 694ms/epoch - 5ms/step
# Epoch 203/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0227 - 682ms/epoch - 5ms/step
# Epoch 204/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0224 - 686ms/epoch - 5ms/step
# Epoch 205/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0224 - 674ms/epoch - 5ms/step
# Epoch 206/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0223 - 669ms/epoch - 5ms/step
# Epoch 207/800
# 134/134 - 1s - loss: 0.0232 - val_loss: 0.0223 - 677ms/epoch - 5ms/step
# Epoch 208/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0225 - 685ms/epoch - 5ms/step
# Epoch 209/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0223 - 804ms/epoch - 6ms/step
# Epoch 210/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0223 - 803ms/epoch - 6ms/step
# Epoch 211/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0228 - 701ms/epoch - 5ms/step
# Epoch 212/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0227 - 679ms/epoch - 5ms/step
# Epoch 213/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0223 - 682ms/epoch - 5ms/step
# Epoch 214/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0226 - 672ms/epoch - 5ms/step
# Epoch 215/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0226 - 679ms/epoch - 5ms/step
# Epoch 216/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0225 - 672ms/epoch - 5ms/step
# Epoch 217/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0224 - 681ms/epoch - 5ms/step
# Epoch 218/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0225 - 698ms/epoch - 5ms/step
# Epoch 219/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0223 - 695ms/epoch - 5ms/step
# Epoch 220/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0223 - 671ms/epoch - 5ms/step
# Epoch 221/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0222 - 679ms/epoch - 5ms/step
# Epoch 222/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0222 - 673ms/epoch - 5ms/step
# Epoch 223/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0224 - 697ms/epoch - 5ms/step
# Epoch 224/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0222 - 692ms/epoch - 5ms/step
# Epoch 225/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0225 - 768ms/epoch - 6ms/step
# Epoch 226/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0222 - 808ms/epoch - 6ms/step
# Epoch 227/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0223 - 714ms/epoch - 5ms/step
# Epoch 228/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0225 - 683ms/epoch - 5ms/step
# Epoch 229/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0222 - 696ms/epoch - 5ms/step
# Epoch 230/800
# 134/134 - 1s - loss: 0.0231 - val_loss: 0.0224 - 692ms/epoch - 5ms/step
# Epoch 231/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0220 - 677ms/epoch - 5ms/step
# Epoch 232/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0224 - 672ms/epoch - 5ms/step
# Epoch 233/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0223 - 678ms/epoch - 5ms/step
# Epoch 234/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0222 - 677ms/epoch - 5ms/step
# Epoch 235/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0225 - 668ms/epoch - 5ms/step
# Epoch 236/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0221 - 689ms/epoch - 5ms/step
# Epoch 237/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0223 - 684ms/epoch - 5ms/step
# Epoch 238/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0223 - 672ms/epoch - 5ms/step
# Epoch 239/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0222 - 699ms/epoch - 5ms/step
# Epoch 240/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0223 - 682ms/epoch - 5ms/step
# Epoch 241/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0224 - 733ms/epoch - 5ms/step
# Epoch 242/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0223 - 802ms/epoch - 6ms/step
# Epoch 243/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0224 - 731ms/epoch - 5ms/step
# Epoch 244/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0226 - 682ms/epoch - 5ms/step
# Epoch 245/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0224 - 672ms/epoch - 5ms/step
# Epoch 246/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0222 - 685ms/epoch - 5ms/step
# Epoch 247/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0224 - 698ms/epoch - 5ms/step
# Epoch 248/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0222 - 695ms/epoch - 5ms/step
# Epoch 249/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0225 - 697ms/epoch - 5ms/step
# Epoch 250/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0225 - 675ms/epoch - 5ms/step
# Epoch 251/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0225 - 689ms/epoch - 5ms/step
# Epoch 252/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0222 - 696ms/epoch - 5ms/step
# Epoch 253/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0222 - 707ms/epoch - 5ms/step
# Epoch 254/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0221 - 713ms/epoch - 5ms/step
# Epoch 255/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0223 - 685ms/epoch - 5ms/step
# Epoch 256/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0226 - 681ms/epoch - 5ms/step
# Epoch 257/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0225 - 726ms/epoch - 5ms/step
# Epoch 258/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0224 - 801ms/epoch - 6ms/step
# Epoch 259/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0222 - 785ms/epoch - 6ms/step
# Epoch 260/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0227 - 705ms/epoch - 5ms/step
# Epoch 261/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0223 - 685ms/epoch - 5ms/step
# Epoch 262/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0222 - 688ms/epoch - 5ms/step
# Epoch 263/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0222 - 690ms/epoch - 5ms/step
# Epoch 264/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0226 - 709ms/epoch - 5ms/step
# Epoch 265/800
# 134/134 - 1s - loss: 0.0230 - val_loss: 0.0225 - 730ms/epoch - 5ms/step
# Epoch 266/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0222 - 685ms/epoch - 5ms/step
# Epoch 267/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0222 - 709ms/epoch - 5ms/step
# Epoch 268/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0222 - 692ms/epoch - 5ms/step
# Epoch 269/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0222 - 701ms/epoch - 5ms/step
# Epoch 270/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0224 - 711ms/epoch - 5ms/step
# Epoch 271/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0221 - 698ms/epoch - 5ms/step
# Epoch 272/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0221 - 698ms/epoch - 5ms/step
# Epoch 273/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0220 - 824ms/epoch - 6ms/step
# Epoch 274/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0221 - 830ms/epoch - 6ms/step
# Epoch 275/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0220 - 779ms/epoch - 6ms/step
# Epoch 276/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0223 - 731ms/epoch - 5ms/step
# Epoch 277/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0222 - 698ms/epoch - 5ms/step
# Epoch 278/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0223 - 712ms/epoch - 5ms/step
# Epoch 279/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0221 - 687ms/epoch - 5ms/step
# Epoch 280/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0224 - 701ms/epoch - 5ms/step
# Epoch 281/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0220 - 725ms/epoch - 5ms/step
# Epoch 282/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0223 - 682ms/epoch - 5ms/step
# Epoch 283/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0221 - 711ms/epoch - 5ms/step
# Epoch 284/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0223 - 691ms/epoch - 5ms/step
# Epoch 285/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0222 - 686ms/epoch - 5ms/step
# Epoch 286/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0221 - 710ms/epoch - 5ms/step
# Epoch 287/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0222 - 700ms/epoch - 5ms/step
# Epoch 288/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0223 - 702ms/epoch - 5ms/step
# Epoch 289/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0231 - 864ms/epoch - 6ms/step
# Epoch 290/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0222 - 844ms/epoch - 6ms/step
# Epoch 291/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0228 - 693ms/epoch - 5ms/step
# Epoch 292/800
# 134/134 - 1s - loss: 0.0229 - val_loss: 0.0222 - 693ms/epoch - 5ms/step
# Epoch 293/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0221 - 732ms/epoch - 5ms/step
# Epoch 294/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0224 - 703ms/epoch - 5ms/step
# Epoch 295/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0223 - 689ms/epoch - 5ms/step
# Epoch 296/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0220 - 692ms/epoch - 5ms/step
# Epoch 297/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0223 - 695ms/epoch - 5ms/step
# Epoch 298/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0226 - 694ms/epoch - 5ms/step
# Epoch 299/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0220 - 689ms/epoch - 5ms/step
# Epoch 300/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0226 - 715ms/epoch - 5ms/step
# Epoch 301/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0222 - 738ms/epoch - 6ms/step
# Epoch 302/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0226 - 685ms/epoch - 5ms/step
# Epoch 303/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0221 - 703ms/epoch - 5ms/step
# Epoch 304/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0230 - 728ms/epoch - 5ms/step
# Epoch 305/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0219 - 831ms/epoch - 6ms/step
# Epoch 306/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0222 - 788ms/epoch - 6ms/step
# Epoch 307/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0222 - 714ms/epoch - 5ms/step
# Epoch 308/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0233 - 701ms/epoch - 5ms/step
# Epoch 309/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0222 - 675ms/epoch - 5ms/step
# Epoch 310/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0227 - 677ms/epoch - 5ms/step
# Epoch 311/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0229 - 698ms/epoch - 5ms/step
# Epoch 312/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0220 - 707ms/epoch - 5ms/step
# Epoch 313/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0226 - 707ms/epoch - 5ms/step
# Epoch 314/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0223 - 709ms/epoch - 5ms/step
# Epoch 315/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0220 - 702ms/epoch - 5ms/step
# Epoch 316/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0221 - 703ms/epoch - 5ms/step
# Epoch 317/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0225 - 687ms/epoch - 5ms/step
# Epoch 318/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0226 - 686ms/epoch - 5ms/step
# Epoch 319/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0221 - 685ms/epoch - 5ms/step
# Epoch 320/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0222 - 702ms/epoch - 5ms/step
# Epoch 321/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0221 - 827ms/epoch - 6ms/step
# Epoch 322/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0226 - 815ms/epoch - 6ms/step
# Epoch 323/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0221 - 699ms/epoch - 5ms/step
# Epoch 324/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0221 - 708ms/epoch - 5ms/step
# Epoch 325/800
# 134/134 - 1s - loss: 0.0228 - val_loss: 0.0223 - 718ms/epoch - 5ms/step
# Epoch 326/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0226 - 680ms/epoch - 5ms/step
# Epoch 327/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0221 - 687ms/epoch - 5ms/step
# Epoch 328/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0222 - 695ms/epoch - 5ms/step
# Epoch 329/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0221 - 682ms/epoch - 5ms/step
# Epoch 330/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0224 - 695ms/epoch - 5ms/step
# Epoch 331/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0221 - 681ms/epoch - 5ms/step
# Epoch 332/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0222 - 725ms/epoch - 5ms/step
# Epoch 333/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0220 - 710ms/epoch - 5ms/step
# Epoch 334/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0221 - 711ms/epoch - 5ms/step
# Epoch 335/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0226 - 690ms/epoch - 5ms/step
# Epoch 336/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0222 - 695ms/epoch - 5ms/step
# Epoch 337/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0221 - 807ms/epoch - 6ms/step
# Epoch 338/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0223 - 803ms/epoch - 6ms/step
# Epoch 339/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0224 - 703ms/epoch - 5ms/step
# Epoch 340/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0221 - 707ms/epoch - 5ms/step
# Epoch 341/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0223 - 680ms/epoch - 5ms/step
# Epoch 342/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0225 - 699ms/epoch - 5ms/step
# Epoch 343/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0221 - 684ms/epoch - 5ms/step
# Epoch 344/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0223 - 722ms/epoch - 5ms/step
# Epoch 345/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0222 - 698ms/epoch - 5ms/step
# Epoch 346/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0224 - 701ms/epoch - 5ms/step
# Epoch 347/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0224 - 682ms/epoch - 5ms/step
# Epoch 348/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0221 - 669ms/epoch - 5ms/step
# Epoch 349/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0224 - 688ms/epoch - 5ms/step
# Epoch 350/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0224 - 717ms/epoch - 5ms/step
# Epoch 351/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0220 - 671ms/epoch - 5ms/step
# Epoch 352/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0222 - 677ms/epoch - 5ms/step
# Epoch 353/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0221 - 775ms/epoch - 6ms/step
# Epoch 354/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0221 - 834ms/epoch - 6ms/step
# Epoch 355/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0220 - 704ms/epoch - 5ms/step
# Epoch 356/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0224 - 691ms/epoch - 5ms/step
# Epoch 357/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0226 - 687ms/epoch - 5ms/step
# Epoch 358/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0223 - 681ms/epoch - 5ms/step
# Epoch 359/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0222 - 711ms/epoch - 5ms/step
# Epoch 360/800
# 134/134 - 1s - loss: 0.0227 - val_loss: 0.0221 - 679ms/epoch - 5ms/step
# Epoch 361/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0222 - 690ms/epoch - 5ms/step
# Epoch 362/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0220 - 709ms/epoch - 5ms/step
# Epoch 363/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0222 - 698ms/epoch - 5ms/step
# Epoch 364/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0221 - 681ms/epoch - 5ms/step
# Epoch 365/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0224 - 700ms/epoch - 5ms/step
# Epoch 366/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0223 - 675ms/epoch - 5ms/step
# Epoch 367/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0224 - 675ms/epoch - 5ms/step
# Epoch 368/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0223 - 672ms/epoch - 5ms/step
# Epoch 369/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0222 - 769ms/epoch - 6ms/step
# Epoch 370/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0223 - 823ms/epoch - 6ms/step
# Epoch 371/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0222 - 690ms/epoch - 5ms/step
# Epoch 372/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0224 - 671ms/epoch - 5ms/step
# Epoch 373/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0221 - 686ms/epoch - 5ms/step
# Epoch 374/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0221 - 687ms/epoch - 5ms/step
# Epoch 375/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0222 - 700ms/epoch - 5ms/step
# Epoch 376/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0221 - 692ms/epoch - 5ms/step
# Epoch 377/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0223 - 686ms/epoch - 5ms/step
# Epoch 378/800
# 134/134 - 1s - loss: 0.0226 - val_loss: 0.0222 - 687ms/epoch - 5ms/step
# Epoch 379/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0221 - 677ms/epoch - 5ms/step
# Epoch 380/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0222 - 708ms/epoch - 5ms/step
# Epoch 381/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0220 - 677ms/epoch - 5ms/step
# Epoch 382/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0223 - 695ms/epoch - 5ms/step
# Epoch 383/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0223 - 706ms/epoch - 5ms/step
# Epoch 384/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0223 - 691ms/epoch - 5ms/step
# Epoch 385/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0222 - 752ms/epoch - 6ms/step
# Epoch 386/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0221 - 800ms/epoch - 6ms/step
# Epoch 387/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0224 - 714ms/epoch - 5ms/step
# Epoch 388/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0220 - 699ms/epoch - 5ms/step
# Epoch 389/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0224 - 691ms/epoch - 5ms/step
# Epoch 390/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0220 - 683ms/epoch - 5ms/step
# Epoch 391/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0220 - 700ms/epoch - 5ms/step
# Epoch 392/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0225 - 684ms/epoch - 5ms/step
# Epoch 393/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0223 - 684ms/epoch - 5ms/step
# Epoch 394/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0228 - 672ms/epoch - 5ms/step
# Epoch 395/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0220 - 702ms/epoch - 5ms/step
# Epoch 396/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0221 - 684ms/epoch - 5ms/step
# Epoch 397/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0219 - 683ms/epoch - 5ms/step
# Epoch 398/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0221 - 680ms/epoch - 5ms/step
# Epoch 399/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0220 - 694ms/epoch - 5ms/step
# Epoch 400/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0225 - 678ms/epoch - 5ms/step
# Epoch 401/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0226 - 830ms/epoch - 6ms/step
# Epoch 402/800
# 134/134 - 1s - loss: 0.0225 - val_loss: 0.0222 - 805ms/epoch - 6ms/step
# Epoch 403/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0222 - 708ms/epoch - 5ms/step
# Epoch 404/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0222 - 687ms/epoch - 5ms/step
# Epoch 405/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0221 - 676ms/epoch - 5ms/step
# Epoch 406/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0222 - 675ms/epoch - 5ms/step
# Epoch 407/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0224 - 691ms/epoch - 5ms/step
# Epoch 408/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0225 - 685ms/epoch - 5ms/step
# Epoch 409/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0219 - 681ms/epoch - 5ms/step
# Epoch 410/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0224 - 683ms/epoch - 5ms/step
# Epoch 411/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0222 - 685ms/epoch - 5ms/step
# Epoch 412/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0220 - 696ms/epoch - 5ms/step
# Epoch 413/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0227 - 672ms/epoch - 5ms/step
# Epoch 414/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0221 - 675ms/epoch - 5ms/step
# Epoch 415/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0221 - 722ms/epoch - 5ms/step
# Epoch 416/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0222 - 694ms/epoch - 5ms/step
# Epoch 417/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0219 - 731ms/epoch - 5ms/step
# Epoch 418/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0221 - 807ms/epoch - 6ms/step
# Epoch 419/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0227 - 737ms/epoch - 6ms/step
# Epoch 420/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0220 - 683ms/epoch - 5ms/step
# Epoch 421/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0219 - 691ms/epoch - 5ms/step
# Epoch 422/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0221 - 709ms/epoch - 5ms/step
# Epoch 423/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0220 - 674ms/epoch - 5ms/step
# Epoch 424/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0220 - 666ms/epoch - 5ms/step
# Epoch 425/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0222 - 691ms/epoch - 5ms/step
# Epoch 426/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0222 - 707ms/epoch - 5ms/step
# Epoch 427/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0221 - 678ms/epoch - 5ms/step
# Epoch 428/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0221 - 693ms/epoch - 5ms/step
# Epoch 429/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0220 - 691ms/epoch - 5ms/step
# Epoch 430/800
# 134/134 - 1s - loss: 0.0224 - val_loss: 0.0221 - 666ms/epoch - 5ms/step
# Epoch 431/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0221 - 680ms/epoch - 5ms/step
# Epoch 432/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0225 - 699ms/epoch - 5ms/step
# Epoch 433/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0221 - 718ms/epoch - 5ms/step
# Epoch 434/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0222 - 810ms/epoch - 6ms/step
# Epoch 435/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0220 - 736ms/epoch - 5ms/step
# Epoch 436/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0220 - 683ms/epoch - 5ms/step
# Epoch 437/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0222 - 675ms/epoch - 5ms/step
# Epoch 438/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0228 - 709ms/epoch - 5ms/step
# Epoch 439/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0224 - 711ms/epoch - 5ms/step
# Epoch 440/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0224 - 696ms/epoch - 5ms/step
# Epoch 441/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0221 - 682ms/epoch - 5ms/step
# Epoch 442/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0221 - 688ms/epoch - 5ms/step
# Epoch 443/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0222 - 676ms/epoch - 5ms/step
# Epoch 444/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0221 - 712ms/epoch - 5ms/step
# Epoch 445/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0222 - 713ms/epoch - 5ms/step
# Epoch 446/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0222 - 686ms/epoch - 5ms/step
# Epoch 447/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0229 - 681ms/epoch - 5ms/step
# Epoch 448/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0222 - 677ms/epoch - 5ms/step
# Epoch 449/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0223 - 700ms/epoch - 5ms/step
# Epoch 450/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0221 - 778ms/epoch - 6ms/step
# Epoch 451/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0220 - 760ms/epoch - 6ms/step
# Epoch 452/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0222 - 705ms/epoch - 5ms/step
# Epoch 453/800
# 134/134 - 1s - loss: 0.0223 - val_loss: 0.0224 - 693ms/epoch - 5ms/step
# Epoch 454/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0226 - 675ms/epoch - 5ms/step
# Epoch 455/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0226 - 689ms/epoch - 5ms/step
# Epoch 456/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0226 - 680ms/epoch - 5ms/step
# Epoch 457/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0222 - 680ms/epoch - 5ms/step
# Epoch 458/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0223 - 704ms/epoch - 5ms/step
# Epoch 459/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0226 - 699ms/epoch - 5ms/step
# Epoch 460/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0221 - 684ms/epoch - 5ms/step
# Epoch 461/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0223 - 700ms/epoch - 5ms/step
# Epoch 462/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0223 - 698ms/epoch - 5ms/step
# Epoch 463/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0223 - 683ms/epoch - 5ms/step
# Epoch 464/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0220 - 691ms/epoch - 5ms/step
# Epoch 465/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0227 - 702ms/epoch - 5ms/step
# Epoch 466/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0221 - 809ms/epoch - 6ms/step
# Epoch 467/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0220 - 767ms/epoch - 6ms/step
# Epoch 468/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0223 - 685ms/epoch - 5ms/step
# Epoch 469/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0224 - 684ms/epoch - 5ms/step
# Epoch 470/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0225 - 679ms/epoch - 5ms/step
# Epoch 471/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0222 - 675ms/epoch - 5ms/step
# Epoch 472/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0220 - 701ms/epoch - 5ms/step
# Epoch 473/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0220 - 683ms/epoch - 5ms/step
# Epoch 474/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0221 - 676ms/epoch - 5ms/step
# Epoch 475/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0222 - 674ms/epoch - 5ms/step
# Epoch 476/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0221 - 678ms/epoch - 5ms/step
# Epoch 477/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0225 - 685ms/epoch - 5ms/step
# Epoch 478/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0223 - 696ms/epoch - 5ms/step
# Epoch 479/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0223 - 675ms/epoch - 5ms/step
# Epoch 480/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0223 - 682ms/epoch - 5ms/step
# Epoch 481/800
# 134/134 - 1s - loss: 0.0222 - val_loss: 0.0221 - 702ms/epoch - 5ms/step
# Epoch 482/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0221 - 752ms/epoch - 6ms/step
# Epoch 483/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0221 - 807ms/epoch - 6ms/step
# Epoch 484/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0223 - 679ms/epoch - 5ms/step
# Epoch 485/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0230 - 671ms/epoch - 5ms/step
# Epoch 486/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0223 - 691ms/epoch - 5ms/step
# Epoch 487/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0221 - 683ms/epoch - 5ms/step
# Epoch 488/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0221 - 699ms/epoch - 5ms/step
# Epoch 489/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0222 - 683ms/epoch - 5ms/step
# Epoch 490/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0222 - 687ms/epoch - 5ms/step
# Epoch 491/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0221 - 669ms/epoch - 5ms/step
# Epoch 492/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0226 - 680ms/epoch - 5ms/step
# Epoch 493/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0226 - 705ms/epoch - 5ms/step
# Epoch 494/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0222 - 696ms/epoch - 5ms/step
# Epoch 495/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0222 - 688ms/epoch - 5ms/step
# Epoch 496/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0223 - 689ms/epoch - 5ms/step
# Epoch 497/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0223 - 678ms/epoch - 5ms/step
# Epoch 498/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0222 - 777ms/epoch - 6ms/step
# Epoch 499/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0224 - 811ms/epoch - 6ms/step
# Epoch 500/800
# 134/134 - 1s - loss: 0.0221 - val_loss: 0.0222 - 715ms/epoch - 5ms/step
# Epoch 501/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0223 - 671ms/epoch - 5ms/step
# Epoch 502/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0220 - 687ms/epoch - 5ms/step
# Epoch 503/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0220 - 696ms/epoch - 5ms/step
# Epoch 504/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0224 - 694ms/epoch - 5ms/step
# Epoch 505/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0221 - 671ms/epoch - 5ms/step
# Epoch 506/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0222 - 694ms/epoch - 5ms/step
# Epoch 507/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0223 - 702ms/epoch - 5ms/step
# Epoch 508/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0226 - 692ms/epoch - 5ms/step
# Epoch 509/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0225 - 680ms/epoch - 5ms/step
# Epoch 510/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0223 - 704ms/epoch - 5ms/step
# Epoch 511/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0226 - 672ms/epoch - 5ms/step
# Epoch 512/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0224 - 678ms/epoch - 5ms/step
# Epoch 513/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0223 - 712ms/epoch - 5ms/step
# Epoch 514/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0228 - 729ms/epoch - 5ms/step
# Epoch 515/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0221 - 797ms/epoch - 6ms/step
# Epoch 516/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0223 - 745ms/epoch - 6ms/step
# Epoch 517/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0224 - 687ms/epoch - 5ms/step
# Epoch 518/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0222 - 690ms/epoch - 5ms/step
# Epoch 519/800
# 134/134 - 1s - loss: 0.0219 - val_loss: 0.0223 - 682ms/epoch - 5ms/step
# Epoch 520/800
# 134/134 - 1s - loss: 0.0220 - val_loss: 0.0221 - 716ms/epoch - 5ms/step
# Epoch 521/800
# 134/134 - 1s - loss: 0.0219 - val_loss: 0.0225 - 670ms/epoch - 5ms/step
# Epoch 522/800
# 134/134 - 1s - loss: 0.0219 - val_loss: 0.0224 - 681ms/epoch - 5ms/step
# Epoch 523/800
# 134/134 - 1s - loss: 0.0219 - val_loss: 0.0225 - 681ms/epoch - 5ms/step
# Epoch 524/800
# 134/134 - 1s - loss: 0.0219 - val_loss: 0.0223 - 666ms/epoch - 5ms/step
# Epoch 525/800
# 134/134 - 1s - loss: 0.0219 - val_loss: 0.0224 - 681ms/epoch - 5ms/step
# Epoch 526/800
# 134/134 - 1s - loss: 0.0219 - val_loss: 0.0224 - 685ms/epoch - 5ms/step
# Epoch 527/800
# 134/134 - 1s - loss: 0.0219 - val_loss: 0.0222 - 703ms/epoch - 5ms/step
# Epoch 528/800
# 134/134 - 1s - loss: 0.0219 - val_loss: 0.0227 - 680ms/epoch - 5ms/step
# Epoch 529/800
# 134/134 - 1s - loss: 0.0219 - val_loss: 0.0223 - 686ms/epoch - 5ms/step
# Epoch 530/800
# 134/134 - 1s - loss: 0.0219 - val_loss: 0.0226 - 727ms/epoch - 5ms/step
# Epoch 531/800
# 134/134 - 1s - loss: 0.0219 - val_loss: 0.0226 - 790ms/epoch - 6ms/step
# Epoch 532/800
# 134/134 - 1s - loss: 0.0219 - val_loss: 0.0221 - 751ms/epoch - 6ms/step
# Epoch 533/800
# 134/134 - 1s - loss: 0.0219 - val_loss: 0.0223 - 713ms/epoch - 5ms/step
# Epoch 534/800
# 134/134 - 1s - loss: 0.0219 - val_loss: 0.0224 - 700ms/epoch - 5ms/step
# Epoch 535/800
# 134/134 - 1s - loss: 0.0219 - val_loss: 0.0223 - 670ms/epoch - 5ms/step
# Epoch 536/800
# 134/134 - 1s - loss: 0.0218 - val_loss: 0.0223 - 676ms/epoch - 5ms/step
# Epoch 537/800
# 134/134 - 1s - loss: 0.0219 - val_loss: 0.0222 - 671ms/epoch - 5ms/step
# Epoch 538/800
# 134/134 - 1s - loss: 0.0218 - val_loss: 0.0227 - 673ms/epoch - 5ms/step
# Epoch 539/800
# 134/134 - 1s - loss: 0.0218 - val_loss: 0.0223 - 676ms/epoch - 5ms/step
# Epoch 540/800
# 134/134 - 1s - loss: 0.0218 - val_loss: 0.0223 - 671ms/epoch - 5ms/step
# Epoch 541/800
# 134/134 - 1s - loss: 0.0218 - val_loss: 0.0223 - 691ms/epoch - 5ms/step
# Epoch 542/800
# 134/134 - 1s - loss: 0.0218 - val_loss: 0.0228 - 701ms/epoch - 5ms/step
# Epoch 543/800
# 134/134 - 1s - loss: 0.0218 - val_loss: 0.0224 - 693ms/epoch - 5ms/step
# Epoch 544/800
# 134/134 - 1s - loss: 0.0218 - val_loss: 0.0222 - 681ms/epoch - 5ms/step
# Epoch 545/800
# 134/134 - 1s - loss: 0.0218 - val_loss: 0.0224 - 672ms/epoch - 5ms/step
# Epoch 546/800
# 134/134 - 1s - loss: 0.0218 - val_loss: 0.0224 - 669ms/epoch - 5ms/step
# Epoch 547/800
# 134/134 - 1s - loss: 0.0218 - val_loss: 0.0222 - 816ms/epoch - 6ms/step
# Epoch 548/800
# 134/134 - 1s - loss: 0.0218 - val_loss: 0.0223 - 799ms/epoch - 6ms/step
# Epoch 549/800
# 134/134 - 1s - loss: 0.0218 - val_loss: 0.0225 - 695ms/epoch - 5ms/step
# Epoch 550/800
# 134/134 - 1s - loss: 0.0218 - val_loss: 0.0225 - 711ms/epoch - 5ms/step
# Epoch 551/800
# 134/134 - 1s - loss: 0.0218 - val_loss: 0.0225 - 676ms/epoch - 5ms/step
# Epoch 552/800
# 134/134 - 1s - loss: 0.0218 - val_loss: 0.0225 - 704ms/epoch - 5ms/step
# Epoch 553/800
# 134/134 - 1s - loss: 0.0218 - val_loss: 0.0225 - 693ms/epoch - 5ms/step
# Epoch 554/800
# 134/134 - 1s - loss: 0.0217 - val_loss: 0.0223 - 673ms/epoch - 5ms/step
# Epoch 555/800
# 134/134 - 1s - loss: 0.0217 - val_loss: 0.0224 - 676ms/epoch - 5ms/step
# Epoch 556/800
# 134/134 - 1s - loss: 0.0217 - val_loss: 0.0224 - 687ms/epoch - 5ms/step
# Epoch 557/800
# 134/134 - 1s - loss: 0.0218 - val_loss: 0.0223 - 704ms/epoch - 5ms/step
# Epoch 558/800
# 134/134 - 1s - loss: 0.0217 - val_loss: 0.0222 - 679ms/epoch - 5ms/step
# Epoch 559/800
# 134/134 - 1s - loss: 0.0217 - val_loss: 0.0229 - 668ms/epoch - 5ms/step
# Epoch 560/800
# ...
# Epoch 615/800
# 134/134 - 1s - loss: 0.0213 - val_loss: 0.0232 - 691ms/epoch - 5ms/step
# Epoch 616/800
# 134/134 - 1s - loss: 0.0213 - val_loss: 0.0228 - 702ms/epoch - 5ms/step
# Epoch 617/800
# 134/134 - 1s - loss: 0.0213 - val_loss: 0.0227 - 695ms/epoch - 5ms/step
# Epoch 618/800
# 134/134 - 1s - loss: 0.0213 - val_loss: 0.0225 - 708ms/epoch - 5ms/step
# Epoch 619/800
# 134/134 - 1s - loss: 0.0213 - val_loss: 0.0228 - 683ms/epoch - 5ms/step
# Epoch 620/800
# 134/134 - 1s - loss: 0.0213 - val_loss: 0.0228 - 705ms/epoch - 5ms/step
# Epoch 621/800
# 134/134 - 1s - loss: 0.0213 - val_loss: 0.0229 - 705ms/epoch - 5ms/step
# Epoch 622/800
# 134/134 - 1s - loss: 0.0213 - val_loss: 0.0225 - 702ms/epoch - 5ms/step
# Epoch 623/800
# 134/134 - 1s - loss: 0.0212 - val_loss: 0.0231 - 690ms/epoch - 5ms/step
# Epoch 624/800
# 134/134 - 1s - loss: 0.0212 - val_loss: 0.0235 - 706ms/epoch - 5ms/step
# Epoch 625/800
# 134/134 - 1s - loss: 0.0212 - val_loss: 0.0226 - 691ms/epoch - 5ms/step
# Epoch 626/800
# 134/134 - 1s - loss: 0.0212 - val_loss: 0.0227 - 688ms/epoch - 5ms/step
# Epoch 627/800
# 134/134 - 1s - loss: 0.0212 - val_loss: 0.0228 - 772ms/epoch - 6ms/step
# Epoch 628/800
# 134/134 - 1s - loss: 0.0212 - val_loss: 0.0226 - 853ms/epoch - 6ms/step
# Epoch 629/800
# 134/134 - 1s - loss: 0.0212 - val_loss: 0.0227 - 703ms/epoch - 5ms/step
# Epoch 630/800
# 134/134 - 1s - loss: 0.0212 - val_loss: 0.0230 - 685ms/epoch - 5ms/step
# Epoch 631/800
# 134/134 - 1s - loss: 0.0212 - val_loss: 0.0229 - 688ms/epoch - 5ms/step
# Epoch 632/800
# 134/134 - 1s - loss: 0.0212 - val_loss: 0.0228 - 685ms/epoch - 5ms/step
# Epoch 633/800
# 134/134 - 1s - loss: 0.0212 - val_loss: 0.0229 - 691ms/epoch - 5ms/step
# Epoch 634/800
# 134/134 - 1s - loss: 0.0212 - val_loss: 0.0228 - 690ms/epoch - 5ms/step
# Epoch 635/800
# 134/134 - 1s - loss: 0.0211 - val_loss: 0.0232 - 707ms/epoch - 5ms/step
# Epoch 636/800
# 134/134 - 1s - loss: 0.0211 - val_loss: 0.0228 - 698ms/epoch - 5ms/step
# Epoch 637/800
# 134/134 - 1s - loss: 0.0211 - val_loss: 0.0228 - 689ms/epoch - 5ms/step
# Epoch 638/800
# 134/134 - 1s - loss: 0.0211 - val_loss: 0.0228 - 722ms/epoch - 5ms/step
# Epoch 639/800
# 134/134 - 1s - loss: 0.0211 - val_loss: 0.0228 - 711ms/epoch - 5ms/step
# Epoch 640/800
# 134/134 - 1s - loss: 0.0211 - val_loss: 0.0230 - 690ms/epoch - 5ms/step
# Epoch 641/800
# 134/134 - 1s - loss: 0.0211 - val_loss: 0.0230 - 701ms/epoch - 5ms/step
# Epoch 642/800
# 134/134 - 1s - loss: 0.0211 - val_loss: 0.0228 - 685ms/epoch - 5ms/step
# Epoch 643/800
# 134/134 - 1s - loss: 0.0211 - val_loss: 0.0236 - 856ms/epoch - 6ms/step
# Epoch 644/800
# 134/134 - 1s - loss: 0.0211 - val_loss: 0.0229 - 793ms/epoch - 6ms/step
# Epoch 645/800
# 134/134 - 1s - loss: 0.0211 - val_loss: 0.0229 - 700ms/epoch - 5ms/step
# Epoch 646/800
# 134/134 - 1s - loss: 0.0211 - val_loss: 0.0230 - 706ms/epoch - 5ms/step
# Epoch 647/800
# 134/134 - 1s - loss: 0.0211 - val_loss: 0.0235 - 709ms/epoch - 5ms/step
# Epoch 648/800
# 134/134 - 1s - loss: 0.0210 - val_loss: 0.0229 - 675ms/epoch - 5ms/step
# Epoch 649/800
# 134/134 - 1s - loss: 0.0210 - val_loss: 0.0229 - 676ms/epoch - 5ms/step
# Epoch 650/800
# 134/134 - 1s - loss: 0.0210 - val_loss: 0.0229 - 690ms/epoch - 5ms/step
# Epoch 651/800
# 134/134 - 1s - loss: 0.0210 - val_loss: 0.0228 - 679ms/epoch - 5ms/step
# Epoch 652/800
# 134/134 - 1s - loss: 0.0210 - val_loss: 0.0228 - 695ms/epoch - 5ms/step
# Epoch 653/800
# 134/134 - 1s - loss: 0.0210 - val_loss: 0.0233 - 677ms/epoch - 5ms/step
# Epoch 654/800
# 134/134 - 1s - loss: 0.0210 - val_loss: 0.0234 - 693ms/epoch - 5ms/step
# Epoch 655/800
# 134/134 - 1s - loss: 0.0210 - val_loss: 0.0228 - 713ms/epoch - 5ms/step
# Epoch 656/800
# 134/134 - 1s - loss: 0.0210 - val_loss: 0.0229 - 686ms/epoch - 5ms/step
# Epoch 657/800
# 134/134 - 1s - loss: 0.0209 - val_loss: 0.0231 - 682ms/epoch - 5ms/step
# Epoch 658/800
# 134/134 - 1s - loss: 0.0209 - val_loss: 0.0235 - 683ms/epoch - 5ms/step
# Epoch 659/800
# 134/134 - 1s - loss: 0.0209 - val_loss: 0.0228 - 780ms/epoch - 6ms/step
# Epoch 660/800
# 134/134 - 1s - loss: 0.0209 - val_loss: 0.0230 - 842ms/epoch - 6ms/step
# Epoch 661/800
# 134/134 - 1s - loss: 0.0209 - val_loss: 0.0230 - 688ms/epoch - 5ms/step
# Epoch 662/800
# 134/134 - 1s - loss: 0.0209 - val_loss: 0.0233 - 683ms/epoch - 5ms/step
# Epoch 663/800
# 134/134 - 1s - loss: 0.0209 - val_loss: 0.0230 - 691ms/epoch - 5ms/step
# Epoch 664/800
# 134/134 - 1s - loss: 0.0209 - val_loss: 0.0230 - 694ms/epoch - 5ms/step
# Epoch 665/800
# 134/134 - 1s - loss: 0.0208 - val_loss: 0.0233 - 684ms/epoch - 5ms/step
# Epoch 666/800
# 134/134 - 1s - loss: 0.0209 - val_loss: 0.0234 - 680ms/epoch - 5ms/step
# Epoch 667/800
# 134/134 - 1s - loss: 0.0209 - val_loss: 0.0229 - 691ms/epoch - 5ms/step
# Epoch 668/800
# 134/134 - 1s - loss: 0.0208 - val_loss: 0.0231 - 681ms/epoch - 5ms/step
# Epoch 669/800
# 134/134 - 1s - loss: 0.0209 - val_loss: 0.0230 - 689ms/epoch - 5ms/step
# Epoch 670/800
# 134/134 - 1s - loss: 0.0208 - val_loss: 0.0231 - 702ms/epoch - 5ms/step
# Epoch 671/800
# 134/134 - 1s - loss: 0.0208 - val_loss: 0.0229 - 702ms/epoch - 5ms/step
# Epoch 672/800
# 134/134 - 1s - loss: 0.0208 - val_loss: 0.0230 - 685ms/epoch - 5ms/step
# Epoch 673/800
# 134/134 - 1s - loss: 0.0208 - val_loss: 0.0228 - 683ms/epoch - 5ms/step
# Epoch 674/800
# 134/134 - 1s - loss: 0.0208 - val_loss: 0.0231 - 696ms/epoch - 5ms/step
# Epoch 675/800
# 134/134 - 1s - loss: 0.0207 - val_loss: 0.0231 - 778ms/epoch - 6ms/step
# Epoch 676/800
# 134/134 - 1s - loss: 0.0207 - val_loss: 0.0228 - 787ms/epoch - 6ms/step
# Epoch 677/800
# 134/134 - 1s - loss: 0.0208 - val_loss: 0.0228 - 716ms/epoch - 5ms/step
# Epoch 678/800
# 134/134 - 1s - loss: 0.0207 - val_loss: 0.0237 - 686ms/epoch - 5ms/step
# Epoch 679/800
# 134/134 - 1s - loss: 0.0207 - val_loss: 0.0232 - 690ms/epoch - 5ms/step
# Epoch 680/800
# 134/134 - 1s - loss: 0.0207 - val_loss: 0.0234 - 704ms/epoch - 5ms/step
# Epoch 681/800
# 134/134 - 1s - loss: 0.0207 - val_loss: 0.0232 - 709ms/epoch - 5ms/step
# Epoch 682/800
# 134/134 - 1s - loss: 0.0207 - val_loss: 0.0231 - 685ms/epoch - 5ms/step
# Epoch 683/800
# 134/134 - 1s - loss: 0.0207 - val_loss: 0.0229 - 683ms/epoch - 5ms/step
# Epoch 684/800
# 134/134 - 1s - loss: 0.0207 - val_loss: 0.0232 - 708ms/epoch - 5ms/step
# Epoch 685/800
# 134/134 - 1s - loss: 0.0207 - val_loss: 0.0233 - 679ms/epoch - 5ms/step
# Epoch 686/800
# 134/134 - 1s - loss: 0.0207 - val_loss: 0.0233 - 685ms/epoch - 5ms/step
# Epoch 687/800
# 134/134 - 1s - loss: 0.0206 - val_loss: 0.0232 - 695ms/epoch - 5ms/step
# Epoch 688/800
# 134/134 - 1s - loss: 0.0206 - val_loss: 0.0234 - 682ms/epoch - 5ms/step
# Epoch 689/800
# 134/134 - 1s - loss: 0.0206 - val_loss: 0.0235 - 701ms/epoch - 5ms/step
# Epoch 690/800
# 134/134 - 1s - loss: 0.0206 - val_loss: 0.0232 - 683ms/epoch - 5ms/step
# Epoch 691/800
# 134/134 - 1s - loss: 0.0206 - val_loss: 0.0237 - 761ms/epoch - 6ms/step
# Epoch 692/800
# 134/134 - 1s - loss: 0.0205 - val_loss: 0.0230 - 800ms/epoch - 6ms/step
# Epoch 693/800
# 134/134 - 1s - loss: 0.0206 - val_loss: 0.0232 - 731ms/epoch - 5ms/step
# Epoch 694/800
# 134/134 - 1s - loss: 0.0205 - val_loss: 0.0233 - 680ms/epoch - 5ms/step
# Epoch 695/800
# 134/134 - 1s - loss: 0.0205 - val_loss: 0.0235 - 687ms/epoch - 5ms/step
# Epoch 696/800
# 134/134 - 1s - loss: 0.0205 - val_loss: 0.0231 - 684ms/epoch - 5ms/step
# Epoch 697/800
# 134/134 - 1s - loss: 0.0206 - val_loss: 0.0234 - 710ms/epoch - 5ms/step
# Epoch 698/800
# 134/134 - 1s - loss: 0.0205 - val_loss: 0.0237 - 698ms/epoch - 5ms/step
# Epoch 699/800
# 134/134 - 1s - loss: 0.0205 - val_loss: 0.0237 - 691ms/epoch - 5ms/step
# Epoch 700/800
# 134/134 - 1s - loss: 0.0205 - val_loss: 0.0232 - 696ms/epoch - 5ms/step
# Epoch 701/800
# 134/134 - 1s - loss: 0.0205 - val_loss: 0.0234 - 676ms/epoch - 5ms/step
# Epoch 702/800
# 134/134 - 1s - loss: 0.0204 - val_loss: 0.0232 - 692ms/epoch - 5ms/step
# Epoch 703/800
# 134/134 - 1s - loss: 0.0204 - val_loss: 0.0235 - 714ms/epoch - 5ms/step
# Epoch 704/800
# 134/134 - 1s - loss: 0.0204 - val_loss: 0.0234 - 702ms/epoch - 5ms/step
# Epoch 705/800
# 134/134 - 1s - loss: 0.0205 - val_loss: 0.0242 - 694ms/epoch - 5ms/step
# Epoch 706/800
# 134/134 - 1s - loss: 0.0204 - val_loss: 0.0234 - 696ms/epoch - 5ms/step
# Epoch 707/800
# 134/134 - 1s - loss: 0.0204 - val_loss: 0.0236 - 774ms/epoch - 6ms/step
# Epoch 708/800
# 134/134 - 1s - loss: 0.0204 - val_loss: 0.0241 - 808ms/epoch - 6ms/step
# Epoch 709/800
# 134/134 - 1s - loss: 0.0204 - val_loss: 0.0233 - 723ms/epoch - 5ms/step
# Epoch 710/800
# 134/134 - 1s - loss: 0.0204 - val_loss: 0.0236 - 727ms/epoch - 5ms/step
# Epoch 711/800
# 134/134 - 1s - loss: 0.0203 - val_loss: 0.0233 - 683ms/epoch - 5ms/step
# Epoch 712/800
# 134/134 - 1s - loss: 0.0204 - val_loss: 0.0235 - 696ms/epoch - 5ms/step
# Epoch 713/800
# 134/134 - 1s - loss: 0.0203 - val_loss: 0.0234 - 685ms/epoch - 5ms/step
# Epoch 714/800
# 134/134 - 1s - loss: 0.0203 - val_loss: 0.0242 - 705ms/epoch - 5ms/step
# Epoch 715/800
# 134/134 - 1s - loss: 0.0203 - val_loss: 0.0243 - 696ms/epoch - 5ms/step
# Epoch 716/800
# 134/134 - 1s - loss: 0.0203 - val_loss: 0.0236 - 701ms/epoch - 5ms/step
# Epoch 717/800
# 134/134 - 1s - loss: 0.0203 - val_loss: 0.0235 - 681ms/epoch - 5ms/step
# Epoch 718/800
# 134/134 - 1s - loss: 0.0203 - val_loss: 0.0236 - 691ms/epoch - 5ms/step
# Epoch 719/800
# 134/134 - 1s - loss: 0.0203 - val_loss: 0.0235 - 714ms/epoch - 5ms/step
# Epoch 720/800
# 134/134 - 1s - loss: 0.0202 - val_loss: 0.0240 - 703ms/epoch - 5ms/step
# Epoch 721/800
# 134/134 - 1s - loss: 0.0202 - val_loss: 0.0235 - 699ms/epoch - 5ms/step
# Epoch 722/800
# 134/134 - 1s - loss: 0.0202 - val_loss: 0.0233 - 716ms/epoch - 5ms/step
# Epoch 723/800
# 134/134 - 1s - loss: 0.0202 - val_loss: 0.0240 - 788ms/epoch - 6ms/step
# Epoch 724/800
# 134/134 - 1s - loss: 0.0202 - val_loss: 0.0239 - 790ms/epoch - 6ms/step
# Epoch 725/800
# 134/134 - 1s - loss: 0.0202 - val_loss: 0.0240 - 737ms/epoch - 5ms/step
# Epoch 726/800
# 134/134 - 1s - loss: 0.0202 - val_loss: 0.0241 - 683ms/epoch - 5ms/step
# Epoch 727/800
# 134/134 - 1s - loss: 0.0202 - val_loss: 0.0237 - 726ms/epoch - 5ms/step
# Epoch 728/800
# 134/134 - 1s - loss: 0.0201 - val_loss: 0.0238 - 701ms/epoch - 5ms/step
# Epoch 729/800
# 134/134 - 1s - loss: 0.0201 - val_loss: 0.0241 - 711ms/epoch - 5ms/step
# Epoch 730/800
# 134/134 - 1s - loss: 0.0201 - val_loss: 0.0237 - 690ms/epoch - 5ms/step
# Epoch 731/800
# 134/134 - 1s - loss: 0.0201 - val_loss: 0.0236 - 703ms/epoch - 5ms/step
# Epoch 732/800
# 134/134 - 1s - loss: 0.0201 - val_loss: 0.0239 - 718ms/epoch - 5ms/step
# Epoch 733/800
# 134/134 - 1s - loss: 0.0200 - val_loss: 0.0235 - 707ms/epoch - 5ms/step
# Epoch 734/800
# 134/134 - 1s - loss: 0.0201 - val_loss: 0.0237 - 679ms/epoch - 5ms/step
# Epoch 735/800
# 134/134 - 1s - loss: 0.0201 - val_loss: 0.0238 - 689ms/epoch - 5ms/step
# Epoch 736/800
# 134/134 - 1s - loss: 0.0201 - val_loss: 0.0237 - 708ms/epoch - 5ms/step
# Epoch 737/800
# 134/134 - 1s - loss: 0.0200 - val_loss: 0.0240 - 665ms/epoch - 5ms/step
# Epoch 738/800
# 134/134 - 1s - loss: 0.0200 - val_loss: 0.0242 - 707ms/epoch - 5ms/step
# Epoch 739/800
# 134/134 - 1s - loss: 0.0200 - val_loss: 0.0239 - 781ms/epoch - 6ms/step
# Epoch 740/800
# 134/134 - 1s - loss: 0.0200 - val_loss: 0.0242 - 805ms/epoch - 6ms/step
# Epoch 741/800
# 134/134 - 1s - loss: 0.0200 - val_loss: 0.0243 - 692ms/epoch - 5ms/step
# Epoch 742/800
# 134/134 - 1s - loss: 0.0199 - val_loss: 0.0236 - 695ms/epoch - 5ms/step
# Epoch 743/800
# 134/134 - 1s - loss: 0.0199 - val_loss: 0.0243 - 704ms/epoch - 5ms/step
# Epoch 744/800
# 134/134 - 1s - loss: 0.0200 - val_loss: 0.0240 - 680ms/epoch - 5ms/step
# Epoch 745/800
# 134/134 - 1s - loss: 0.0200 - val_loss: 0.0237 - 690ms/epoch - 5ms/step
# Epoch 746/800
# 134/134 - 1s - loss: 0.0199 - val_loss: 0.0239 - 682ms/epoch - 5ms/step
# Epoch 747/800
# 134/134 - 1s - loss: 0.0198 - val_loss: 0.0243 - 702ms/epoch - 5ms/step
# Epoch 748/800
# 134/134 - 1s - loss: 0.0199 - val_loss: 0.0236 - 675ms/epoch - 5ms/step
# Epoch 749/800
# 134/134 - 1s - loss: 0.0199 - val_loss: 0.0238 - 686ms/epoch - 5ms/step
# Epoch 750/800
# 134/134 - 1s - loss: 0.0198 - val_loss: 0.0239 - 686ms/epoch - 5ms/step
# Epoch 751/800
# 134/134 - 1s - loss: 0.0198 - val_loss: 0.0239 - 707ms/epoch - 5ms/step
# Epoch 752/800
# 134/134 - 1s - loss: 0.0199 - val_loss: 0.0239 - 698ms/epoch - 5ms/step
# Epoch 753/800
# 134/134 - 1s - loss: 0.0198 - val_loss: 0.0244 - 713ms/epoch - 5ms/step
# Epoch 754/800
# 134/134 - 1s - loss: 0.0198 - val_loss: 0.0238 - 700ms/epoch - 5ms/step
# Epoch 755/800
# 134/134 - 1s - loss: 0.0198 - val_loss: 0.0241 - 760ms/epoch - 6ms/step
# Epoch 756/800
# 134/134 - 1s - loss: 0.0198 - val_loss: 0.0238 - 813ms/epoch - 6ms/step
# Epoch 757/800
# 134/134 - 1s - loss: 0.0198 - val_loss: 0.0239 - 702ms/epoch - 5ms/step
# Epoch 758/800
# 134/134 - 1s - loss: 0.0197 - val_loss: 0.0246 - 681ms/epoch - 5ms/step
# Epoch 759/800
# 134/134 - 1s - loss: 0.0197 - val_loss: 0.0242 - 684ms/epoch - 5ms/step
# Epoch 760/800
# 134/134 - 1s - loss: 0.0197 - val_loss: 0.0242 - 693ms/epoch - 5ms/step
# Epoch 761/800
# 134/134 - 1s - loss: 0.0197 - val_loss: 0.0245 - 673ms/epoch - 5ms/step
# Epoch 762/800
# 134/134 - 1s - loss: 0.0197 - val_loss: 0.0245 - 701ms/epoch - 5ms/step
# Epoch 763/800
# 134/134 - 1s - loss: 0.0197 - val_loss: 0.0244 - 723ms/epoch - 5ms/step
# Epoch 764/800
# 134/134 - 1s - loss: 0.0196 - val_loss: 0.0241 - 678ms/epoch - 5ms/step
# Epoch 765/800
# 134/134 - 1s - loss: 0.0196 - val_loss: 0.0245 - 677ms/epoch - 5ms/step
# Epoch 766/800
# 134/134 - 1s - loss: 0.0196 - val_loss: 0.0243 - 683ms/epoch - 5ms/step
# Epoch 767/800
# 134/134 - 1s - loss: 0.0196 - val_loss: 0.0245 - 692ms/epoch - 5ms/step
# Epoch 768/800
# 134/134 - 1s - loss: 0.0196 - val_loss: 0.0251 - 683ms/epoch - 5ms/step
# Epoch 769/800
# 134/134 - 1s - loss: 0.0196 - val_loss: 0.0241 - 705ms/epoch - 5ms/step
# Epoch 770/800
# 134/134 - 1s - loss: 0.0196 - val_loss: 0.0243 - 685ms/epoch - 5ms/step
# Epoch 771/800
# 134/134 - 1s - loss: 0.0196 - val_loss: 0.0245 - 767ms/epoch - 6ms/step
# Epoch 772/800
# 134/134 - 1s - loss: 0.0195 - val_loss: 0.0243 - 797ms/epoch - 6ms/step
# Epoch 773/800
# 134/134 - 1s - loss: 0.0195 - val_loss: 0.0249 - 693ms/epoch - 5ms/step
# Epoch 774/800
# 134/134 - 1s - loss: 0.0196 - val_loss: 0.0246 - 692ms/epoch - 5ms/step
# Epoch 775/800
# 134/134 - 1s - loss: 0.0195 - val_loss: 0.0240 - 695ms/epoch - 5ms/step
# Epoch 776/800
# 134/134 - 1s - loss: 0.0195 - val_loss: 0.0242 - 699ms/epoch - 5ms/step
# Epoch 777/800
# 134/134 - 1s - loss: 0.0195 - val_loss: 0.0247 - 680ms/epoch - 5ms/step
# Epoch 778/800
# 134/134 - 1s - loss: 0.0194 - val_loss: 0.0241 - 676ms/epoch - 5ms/step
# Epoch 779/800
# 134/134 - 1s - loss: 0.0194 - val_loss: 0.0244 - 676ms/epoch - 5ms/step
# Epoch 780/800
# 134/134 - 1s - loss: 0.0194 - val_loss: 0.0246 - 681ms/epoch - 5ms/step
# Epoch 781/800
# 134/134 - 1s - loss: 0.0194 - val_loss: 0.0248 - 695ms/epoch - 5ms/step
# Epoch 782/800
# 134/134 - 1s - loss: 0.0194 - val_loss: 0.0243 - 689ms/epoch - 5ms/step
# Epoch 783/800
# 134/134 - 1s - loss: 0.0194 - val_loss: 0.0242 - 679ms/epoch - 5ms/step
# Epoch 784/800
# 134/134 - 1s - loss: 0.0193 - val_loss: 0.0245 - 683ms/epoch - 5ms/step
# Epoch 785/800
# 134/134 - 1s - loss: 0.0193 - val_loss: 0.0247 - 692ms/epoch - 5ms/step
# Epoch 786/800
# 134/134 - 1s - loss: 0.0193 - val_loss: 0.0243 - 693ms/epoch - 5ms/step
# Epoch 787/800
# 134/134 - 1s - loss: 0.0193 - val_loss: 0.0247 - 841ms/epoch - 6ms/step
# Epoch 788/800
# 134/134 - 1s - loss: 0.0193 - val_loss: 0.0241 - 845ms/epoch - 6ms/step
# Epoch 789/800
# 134/134 - 1s - loss: 0.0193 - val_loss: 0.0251 - 687ms/epoch - 5ms/step
# Epoch 790/800
# 134/134 - 1s - loss: 0.0193 - val_loss: 0.0243 - 680ms/epoch - 5ms/step
# Epoch 791/800
# 134/134 - 1s - loss: 0.0193 - val_loss: 0.0244 - 706ms/epoch - 5ms/step
# Epoch 792/800
# 134/134 - 1s - loss: 0.0193 - val_loss: 0.0251 - 712ms/epoch - 5ms/step
# Epoch 793/800
# 134/134 - 1s - loss: 0.0192 - val_loss: 0.0250 - 694ms/epoch - 5ms/step
# Epoch 794/800
# 134/134 - 1s - loss: 0.0192 - val_loss: 0.0247 - 702ms/epoch - 5ms/step
# Epoch 795/800
# 134/134 - 1s - loss: 0.0192 - val_loss: 0.0250 - 687ms/epoch - 5ms/step
# Epoch 796/800
# 134/134 - 1s - loss: 0.0192 - val_loss: 0.0247 - 713ms/epoch - 5ms/step
# Epoch 797/800
# 134/134 - 1s - loss: 0.0191 - val_loss: 0.0244 - 702ms/epoch - 5ms/step
# Epoch 798/800
# 134/134 - 1s - loss: 0.0191 - val_loss: 0.0246 - 705ms/epoch - 5ms/step
# Epoch 799/800
# 134/134 - 1s - loss: 0.0191 - val_loss: 0.0246 - 701ms/epoch - 5ms/step
# Epoch 800/800
# 134/134 - 1s - loss: 0.0191 - val_loss: 0.0246 - 698ms/epoch - 5ms/step

# %%
 # Graficar curvas de entrenamiento y validación
 # para verificar que no existe overfitting
plt.plot(historia.history['loss'],label='RMSE train')
plt.plot(historia.history['val_loss'],label='RMSE val')
plt.xlabel('Iteración')
plt.ylabel('RMSE')
plt.legend();

# %% [markdown]
# ## 5. Desempeño del modelo

# %%
# Cálculo de rmses para train, val y test
rmse_tr = modelo.evaluate(x=x_tr_s, y=y_tr_s, verbose=0)
rmse_vl = modelo.evaluate(x=x_vl_s, y=y_vl_s, verbose=0)
rmse_ts = modelo.evaluate(x=x_ts_s, y=y_ts_s, verbose=0)

# Imprimir resultados en pantalla
print('Comparativo desempeños:')
print(f'  RMSE train:\t {rmse_tr:.3f}')
print(f'  RMSE val:\t {rmse_vl:.3f}')
print(f'  RMSE test:\t {rmse_ts:.3f}')
# Out:
# Comparativo desempeños:
#   RMSE train:	 0.018
#   RMSE val:	 0.024
#   RMSE test:	 0.029

# %% [markdown]
# ##6. Predicciones con el modelo entrenado

# %%
def predecir(x, model, scaler):
    '''Genera la predicción de OUTPUT_LENGTH instantes
    de tiempo a futuro con el modelo entrenado.

    Entrada:
    - x: batch (o batches) de datos para ingresar al modelo
      (tamaño: BATCHES X INPUT_LENGTH X FEATURES)
    - model: Red LSTM entrenada
    - scaler: escalador (requerido para llevar la predicción a la escala original)

    Salida:
    - y_pred: la predicción en la escala original (tamaño: BATCHES X OUTPUT_LENGTH X FEATURES)
    '''

    # Calcular predicción escalada en el rango de -1 a 1
    y_pred_s = model.predict(x,verbose=0)

    # Llevar la predicción a la escala original
    y_pred = scaler.inverse_transform(y_pred_s)

    return y_pred.flatten()

# %%
# Calcular predicciones sobre el set de prueba
y_ts_pred = predecir(x_ts_s, modelo, scaler)

# %% [markdown]
# Analicemos este desempeño gráficamente mostrando las temperaturas originales y las predichas por el modelo para cada uno de los datos en el set de prueba:

# %%
N = len(y_ts_pred)    # Número de predicciones
ndato = np.linspace(1,N,N)

# Cálculo de errores simples
errores = y_ts.flatten()-y_ts_pred
plt.fill_between(ndato, 2, -2, color='red', alpha=0.5)
plt.plot(errores)

# %%
f = plt.figure(figsize=(10,5))
plt.plot(y_ts_pred[:150], color='orange', label='Predicción')
plt.plot(y_ts.flatten()[:150], label='Original')
plt.legend()
plt.title("Predicción del modelo")
# Out:
# Text(0.5, 1.0, 'Predicción del modelo')
